# %% [markdown]
# # Programming Assignment #1
# ## By: Averie Stunz

# %%
name = "George"
sport = "soccer"
goals = 3
hours = 1.5
team = "Bulldogs"
action = "ran"
score = 2
updated_score = score + 1
exclamation = "Yay" 
updated_team = team.upper()

my_paragraph = f"Once when a dog named {name} was playing an important championship {sport} game with the {team},"\
               f" they were tied {score} to {score}."\
               f" But in the last second {name} {action} across the field without stopping, taking the ball away from the last defender and scored!"\
               f" In {hours} hours, {name} scored {goals} amazing goals to help win the game."\
               f" The crowd shouted {exclamation} {updated_team}!!!"\
               f" The {team} won the game with a final score of {updated_score} to {score}!"
print(my_paragraph)
# Out:
# Once when a dog named George was playing an important championship soccer game with the Bulldogs, they were tied 2 to 2. But in the last second George ran across the field without stopping, taking the ball away from the last defender and scored! In 1.5 hours, George scored 3 amazing goals to help win the game. The crowd shouted Yay BULLDOGS!!! The Bulldogs won the game with a final score of 3 to 2!
