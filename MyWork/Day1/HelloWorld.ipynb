# %% [markdown]
# ## Welcome to Python Programming!
#
# - In this class you will learn all the basics of programming (in general) and about the python language (in particular).
# - Using any form of AI to generate your code before you have writen it yourself is againts the rulles of this class and will constitute plagiarism. After you have a working version of your code, you may try out the AI solution to see how they are different.

# %%
# Your first code: Hello World

print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### Jupyter Notebooks and Google Colab
#
# - Great for trying out code and exploring possible solutions
# - You can debug line by line
#
# - Not great for writing professional code
# - Not compact or optimized

# %% [markdown]
# ### Python using PyCharm or another IDE
#
# - This is the industry standard for programming large projects in Python
# - Your code should run independently of a browser and on your local machine.
#
# - Harder to debug, especially as the code gets very long or complicated

# %%
a = 4
b = 6
c = a + b
print(c)
# Out:
# 10
